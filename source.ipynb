# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("master.csv")
data = data.reset_index()
data.head(4)
# Out:
#    index  country  year     sex          age  suicides_no  population  \
# 0      0  Albania  1987    male  15-24 years           21      312900
# 1      1  Albania  1987    male  35-54 years           16      308000
# 2      2  Albania  1987  female  15-24 years           14      289700
# 3      3  Albania  1987    male    75+ years            1       21800
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# 3                 796  G.I. Generation

# %%
temp = data[(data["country"] == "United States") | (data["country"] == "Canada") | (data["country"] == "Mexico")]
temp
# Out:
#        index        country  year     sex          age  suicides_no  \
# 4916    4916         Canada  1985    male    75+ years          111
# 4917    4917         Canada  1985    male  55-74 years          502
# 4918    4918         Canada  1985    male  25-34 years          605
# 4919    4919         Canada  1985    male  35-54 years          774
# 4920    4920         Canada  1985    male  15-24 years          560
# ...      ...            ...   ...     ...          ...          ...
# 27215  27215  United States  2015  female  25-34 years         1444
# 27216  27216  United States  2015  female  15-24 years         1132
# 27217  27217  United States  2015  female    75+ years          540
# 27218  27218  United States  2015    male   5-14 years          255
# 27219  27219  United States  2015  female   5-14 years          158
#
#        population  suicides/100k pop       country-year  HDI for year  \
# 4916       390200              28.45         Canada1985         0.827
# ...

# %%
temp.columns
# Out:
# Index(['index', 'country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k pop', 'country-year', 'HDI for year',
#        ' gdp_for_year ($) ', 'gdp_per_capita ($)', 'generation'],
#       dtype='object')

# %%
temp = temp.drop(columns = ["HDI for year", "country-year"])
temp = temp.rename(columns = {"suicides/100k pop": "suicides_100k", " gdp_for_year ($) ": "gdp_yearly", "gdp_per_capita ($)": "gdp_capita"})

# %%
temp.to_csv(r"gdp_mod.csv", index = False, header = True, mode = "w")
